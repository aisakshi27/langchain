# %% [markdown]
# # Document loaders

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("testFile.txt")
loader
text_doc = loader.load()
text_doc
# Out:
# [Document(metadata={'source': 'testFile.txt'}, page_content='This is Sakshi')]

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("testPDF.pdf")
docs =loader.load()
docs
# Out:
# [Document(metadata={'producer': 'iOS Version 26.2.1 (Build 23C71) Quartz PDFContext', 'creator': 'PyPDF', 'creationdate': "D:20260228100945Z00'00'", 'moddate': "D:20260228100945Z00'00'", 'source': 'testPDF.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='')]
